# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
path = 'MerahPutih.jpg'


f = cv2.imread(path,0)

plt.imshow(f, cmap='gray')

print(f)
# Out:
# [[ 94  94  94 ...  94  94  94]
#  [ 94  94  94 ...  94  94  94]
#  [ 94  94  94 ...  94  94  94]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
F = np.fft.fft2(f)
plt.imshow(np.log1p(np.abs(F)),cmap='gray')

# %%
Fshift = np.fft.fftshift(F)

plt.imshow(np.log1p(np.abs(Fshift)),cmap='gray')

# %%
Fshiftback = np.fft.ifftshift(Fshift)

plt.imshow(np.log1p(np.abs(Fshiftback)),cmap='gray')

# %%
fback = np.abs(np.fft.ifft2(Fshiftback))

plt.imshow(fback, cmap='gray')

# %%
print(f)

print(fback)
# Out:
# [[ 94  94  94 ...  94  94  94]
#  [ 94  94  94 ...  94  94  94]
#  [ 94  94  94 ...  94  94  94]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# [[ 94.  94.  94. ...  94.  94.  94.]
#  [ 94.  94.  94. ...  94.  94.  94.]
#  [ 94.  94.  94. ...  94.  94.  94.]
#  ...
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]]
